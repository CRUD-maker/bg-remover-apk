# %% [markdown]
# # Build Your Android App (.apk) - Bleeding Edge Fix
# **Developed by Faseeh Ansari**
#
# We are switching to the **Development Version** of the build tools.
# The standard version is currently broken on Google Colab's latest update.
#
# **CRITICAL STEP**:
# 1. **Runtime -> Disconnect and Delete Runtime** (Clear the old broken tools).
# 2. Run **Setup Environment**.
# 3. Upload `main.py`, `buildozer.spec`, `remover_mobile.py`.
# 4. Run **Build APK**.

# %%
# Install Development versions (Fixes recipe bugs)
# !pip install git+https://github.com/kivy/buildozer.git
# !pip install git+https://github.com/kivy/python-for-android.git

# Install System Dependencies
# !sudo apt-get update
# !sudo apt-get install -y python3-pip build-essential git python3 python3-dev ffmpeg \
    libsdl2-dev libsdl2-image-dev libsdl2-mixer-dev libsdl2-ttf-dev libportmidi-dev \
    libswscale-dev libavformat-dev libavcodec-dev zlib1g-dev \
    libtool libtool-bin automake autoconf pkg-config libffi-dev libltdl-dev

# Force path for aclocal
import os
os.environ['ACLOCAL_PATH'] = '/usr/share/aclocal'

# %%
# Build
# !buildozer android debug
